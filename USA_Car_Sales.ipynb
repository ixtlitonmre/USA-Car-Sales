# %%
import pandas as pd

# %%
car_sales_original_df = pd.read_csv("car_data.csv")

# %%
car_sales_original_df.head(5)
# Out:
#          Car_id      Date Customer Name Gender  Annual Income  \
# 0  C_CND_000001  1/2/2022     Geraldine   Male          13500
# 1  C_CND_000002  1/2/2022           Gia   Male        1480000
# 2  C_CND_000003  1/2/2022        Gianna   Male        1035000
# 3  C_CND_000004  1/2/2022       Giselle   Male          13500
# 4  C_CND_000005  1/2/2022         Grace   Male        1465000
#
#                            Dealer_Name   Company       Model  \
# 0  Buddy Storbeck's Diesel Service Inc      Ford  Expedition
# 1                     C & M Motors Inc     Dodge     Durango
# 2                          Capitol KIA  Cadillac    Eldorado
# 3               Chrysler of Tri-Cities    Toyota      Celica
# 4                    Chrysler Plymouth     Acura          TL
#
#                       Engine Transmission       Color  Price ($)  Dealer_No   \
# 0  DoubleÂ Overhead Camshaft         Auto       Black      26000  06457-3834
# ...

# %%
car_sales_original_df.tail(5)
# Out:
#              Car_id        Date Customer Name  Gender  Annual Income  \
# 23901  C_CND_023902  12/31/2023        Martin    Male          13500
# 23902  C_CND_023903  12/31/2023         Jimmy  Female         900000
# 23903  C_CND_023904  12/31/2023          Emma    Male         705000
# 23904  C_CND_023905  12/31/2023      Victoire    Male          13500
# 23905  C_CND_023906  12/31/2023       Donovan    Male        1225000
#
#                           Dealer_Name    Company    Model  \
# 23901                C & M Motors Inc   Plymouth  Voyager
# 23902  Ryder Truck Rental and Leasing  Chevrolet    Prizm
# 23903          Chrysler of Tri-Cities        BMW     328i
# 23904               Chrysler Plymouth  Chevrolet    Metro
# 23905                 Pars Auto Sales      Lexus    ES300
#
#                           Engine Transmission       Color  Price ($)  \
# 23901          Overhead Camshaft       Manual         Red      12000
# ...

# %%
car_sales_original_df.shape
# Out:
# (23906, 16)

# %%
car_sales_original_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Car_id         23906 non-null  str
#  1   Date           23906 non-null  str
#  2   Customer Name  23905 non-null  str
#  3   Gender         23906 non-null  str
#  4   Annual Income  23906 non-null  int64
#  5   Dealer_Name    23906 non-null  str
#  6   Company        23906 non-null  str
#  7   Model          23906 non-null  str
#  8   Engine         23906 non-null  str
#  9   Transmission   23906 non-null  str
#  10  Color          23906 non-null  str
#  11  Price ($)      23906 non-null  int64
#  12  Dealer_No      23906 non-null  str
#  13  Body Style     23906 non-null  str
#  14  Phone          23906 non-null  int64
#  15  Dealer_Region  23906 non-null  str
# dtypes: int64(3), str(13)
# memory usage: 2.9 MB

# %%
car_sales_original_df.nunique()
# Out:
# Car_id           23906
# Date               612
# Customer Name     3021
# Gender               2
# Annual Income     2508
# Dealer_Name         28
# Company             30
# Model              154
# Engine               2
# Transmission         2
# Color                3
# Price ($)          870
# Dealer_No            7
# Body Style           5
# Phone            23804
# Dealer_Region        7
# dtype: int64

# %%
car_sales_original_df.describe(include='all')
# Out:
#               Car_id      Date Customer Name Gender  Annual Income  \
# count          23906     23906         23905  23906   2.390600e+04
# unique         23906       612          3021      2            NaN
# top     C_CND_000001  9/5/2023        Thomas   Male            NaN
# freq               1       190            92  18798            NaN
# mean             NaN       NaN           NaN    NaN   8.308403e+05
# std              NaN       NaN           NaN    NaN   7.200064e+05
# min              NaN       NaN           NaN    NaN   1.008000e+04
# 25%              NaN       NaN           NaN    NaN   3.860000e+05
# 50%              NaN       NaN           NaN    NaN   7.350000e+05
# 75%              NaN       NaN           NaN    NaN   1.175750e+06
# max              NaN       NaN           NaN    NaN   1.120000e+07
#
#                                             Dealer_Name    Company     Model  \
# count                                             23906      23906     23906
# ...

# %%
car_sales_df = car_sales_original_df.drop(['Car_id', 'Customer Name', 'Dealer_Name', 'Engine', 'Transmission','Dealer_No ', 'Phone'], axis=1)

# %%
car_sales_df['Date'] = pd.to_datetime(car_sales_df['Date'], errors='coerce')
car_sales_df.rename(columns={'Price ($)': 'Price', 'Annual Income': 'Annual_Income', 'Body Style': 'Body_Style'}, inplace=True)

# %%
car_sales_df.shape
# Out:
# (23906, 9)

# %%
car_sales_df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 23906 entries, 0 to 23905
# Data columns (total 9 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Date           23906 non-null  datetime64[us]
#  1   Gender         23906 non-null  str
#  2   Annual_Income  23906 non-null  int64
#  3   Company        23906 non-null  str
#  4   Model          23906 non-null  str
#  5   Color          23906 non-null  str
#  6   Price          23906 non-null  int64
#  7   Body_Style     23906 non-null  str
#  8   Dealer_Region  23906 non-null  str
# dtypes: datetime64[us](1), int64(2), str(6)
# memory usage: 1.6 MB

# %%
car_sales_df.head(5)
# Out:
#         Date Gender  Annual_Income   Company       Model       Color  Price  \
# 0 2022-01-02   Male          13500      Ford  Expedition       Black  26000
# 1 2022-01-02   Male        1480000     Dodge     Durango       Black  19000
# 2 2022-01-02   Male        1035000  Cadillac    Eldorado         Red  31500
# 3 2022-01-02   Male          13500    Toyota      Celica  Pale White  14000
# 4 2022-01-02   Male        1465000     Acura          TL         Red  24500
#
#   Body_Style Dealer_Region
# 0        SUV    Middletown
# 1        SUV        Aurora
# 2  Passenger    Greenville
# 3        SUV         Pasco
# 4  Hatchback    Janesville

# %%
for col in car_sales_original_df.select_dtypes(include='str').columns:
    has_trailing_space = car_sales_original_df[col].astype(str).str.endswith(' ').any()
    print(col, has_trailing_space)
# Out:
# Car_id False
# Date False
# Customer Name False
# Gender False
# Dealer_Name False
# Company False
# Model False
# Engine False
# Transmission False
# Color False
# Dealer_No  False
# Body Style False
# Dealer_Region False
